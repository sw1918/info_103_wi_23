# %% [markdown]
# # Practice: Timed actions

# %% [markdown]
# What if you don't want something to run forever? In this practice, you'll combine schedule and datetime to create a loop that says "Happy new minute!" every minute, and stops after 5 minutes.

# %% [markdown]
# ## Timed actions
# load `datetime` library and `time` library that helps us with scheduling.

# %%
from time import sleep
from datetime import datetime

# %% [markdown]
# If we call datetime.now(), we get a datetime object that describes the exact time and date right now.

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 12, 14, 13, 40, 27, 108892)

# %% [markdown]
# You can also subtract two datetime objects to get a timedelta object, which describes the difference between two datetimes.

# %%
t1 = datetime.now()
sleep(3)
t2 = datetime.now()
tdif = t2 - t1
print(t1)
print(t2)
print(tdif)
# Out:
# 2025-12-14 13:47:39.920210
# 2025-12-14 13:47:42.922971
# 0:00:03.002761

# %% [markdown]
# If you want to turn that timedelta object into a number we can work with in python, you can convert it into seconds:

# %%
tdif.total_seconds()
# Out:
# 3.002761

# %% [markdown]
# ## Try it yourself!
# Define a function that detects when a new minute has passed (e.g. we change from 9:50am to 9:51pm), and prints out "Happy new minute!" Keep track of how often it says it, and stop the function after three iterations.

# %%
def say_happy_minute():
    print("Happy new minute!")

#TODO: Create a loop that calls say_happy_minute() every minute at roughly the X:00, and stops after three iterations
