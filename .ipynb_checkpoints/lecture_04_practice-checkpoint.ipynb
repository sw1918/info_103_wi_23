# %% [markdown]
# # Lecture 4 Practice: Data
#
# ## Follow along with lecture!
#
# Examples of statements that return Boolean values:

# %%
5 > 1 # Is 5 greater than 1?

# %%
2 == 3 # Does 2 equal 3?

# %%
"C" in "Cat" #Is the string C in the string Cat?

# %%
my_var = 0
my_var is my_var #Is my_var the same object as my_var?

# %%
1 == 0 or 1 > 0 # Does 1 equal 0 OR is 1 greater than 0?

# %% [markdown]
# Some helpful math functions:

# %%
x = max(1, 19, 0, 555)
print(x)

# %%
x = min(1, 19, 0, 555)
print(x)

# %%
x = round(0.999999999)
print(x)

# %% [markdown]
# Some helpful string functions

# %%
x = "hi there"
print(x.upper())

# %%
x = "DON’T talk so loud"
print(x.lower())

# %%
x = "Dogs and " + "cats"
print(x)

# %%
x = x.replace("cats", "fish")
print(x)

# %% [markdown]
# You can cast variables to assert what data type they're supposed to be. This has several uses:

# %%
5 + int(5)

# %%
"How many cats do I have? I have " + str(9)

# %% [markdown]
# ## Try it yourself!
#
# Below are some variables that store the number of likes from different posts:

# %%
post_a = 5
post_b = 10
post_c = 512
post_d = 1

# %% [markdown]
# We want to know the range of likes between those posts. Write a statement that finds the max and the min from that list, subtracts the max - min, and stores the resulting number in a variable.

# %%
max = #TODO: Find the max using a function
min = #TODO: Find the min using a function
#TODO: Store max - min in a variable

# %% [markdown]
# Now, using string addition/concatenation, print out a statement that explains what that number means by transforming your variable to a string and adding it to another string. The output should be something like, "The range of likes was {x}"

# %%
#TODO: Your code here
