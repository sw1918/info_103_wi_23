# %% [markdown]
# # Lab 1: Make One Bluesky Post

# %% [markdown]
# ## Running this Jupyter Notebook
# This page is called a "Jupyter Notebook" which it is a text page that has runnable Python code in it.
#
# You are hopefully looking at this Jupyter Notebook in a code editor called Jupyter Lab
#
# ![a screenshot of this page viewed in jupyter lab, with menus and options above the editable page](../imgs/jupyter_lab.png)
#
# In Jupyter Lab you can double click any section to edit it, and you can press the triangle "run" button to run the code (or displayed the text).
#
# ![a screenshot of this page viewed in jupyter lab,with the triangle "run" button circled. Next to it are a square "interrupt the kernal" button and other options](../imgs/jupyter_run_code.png)
#
# When the code runs, the little number to the left of the code block should change. There might also be some output from your action displyed below the code block.
#
# So now you can go through the rest of this page and select and run each section of code.

# %% [markdown]
# ## Here is the bot code you can run!
# Our demo Reddit bot code is below, broken up into different sections.
#
# You can select each section of the code below and run it to see what it does.
#
# By default this code uses a fake version of our Reddit connection so it doesn't connect to a real Reddit account.
#
# If you want to actually connect to your Reddit account, you can put your special developer access passwords in the reddit_keys.py file, and then when you run the code make sure to skip the code section that makes a fake Reddit connection with "fake_praw".

# %% [markdown]
# ### Step 1: Load Tweepy code

# %%
# Load some code called "Client" from the "atproto" library that will help us work with Bluesky
from atproto import Client

# %% [markdown]
# ### (Optional) Step 1b: Make a fake Bluesky connection with the fake_atproto library
# For testing purposes, we"ve added this line of code, which loads a fake version of atproto, so it wont actually connect to Bluesky. __If you want to try to actually connect to Bluesky, don't run this line of code.__

# %%
# %run fake_apis/fake_atproto.ipynb

# %% [markdown]
# ### Step 2: Load your Bluesky account credentials
# For this class we are saving our Bluesky handle and password in a separate file called bluesky_keys.py. This way we only have to copy the keys in once, and people looking at our screens (mostly) wont be able to see our password!
#
# If you haven't already, please [set up your Bluesky bot using the instructions in hte textbook](https://social-media-ethics-automation.github.io/book/bsky/appendix/making_bot_account.html), and copy-paste the handle and password into your bluesky-keys file. Note that you shouldn't copy-paste the "@" symbol into the file.
#
# After you copy your values into the bluesky_keys.py file, make sure that file is saved, and then you might have to restart the kernal on this notebook with either the circle arrow button:

# %%
# Login to Bluesky
# %run bluesky_keys.py

client = Client(base_url="https://bsky.social")
client.login(handle, password)

# %% [markdown]
# ### Step 3: Submit a post to Bluesky

# %%
# Post on Bluesky
client.send_post("This post was made by a computer program!")

# %% [markdown]
# ### Step 4: Modify the code above to create a different Bluesky post (as long as it doesn't violate community guidelines)
