# %% [markdown]
# # Lab 4: Encouragement bot
#
# In this lab, you're going to combine what you've learned about conditionals and string manipulation to see if you can automatically detect if a social media user needs a little encouragement!
#
# Your job is to look for strings that include the pattern "I am {blank}", and figure out if the "{blank}" part is a negative word. If it is, you need to create a sentence that gives the user some encouragement!
#
# Let's start by defining a list of negative words:

# %%
negative_words = ["stupid", "ugly", "annoying", "cringe"]

# %% [markdown]
# Now, try to write some code that detects if a given sentence includes one of these negative words. If it does, you should set a new variable "response" that uses the keyword and negates it in some way. For example: "No, you are not {blank}" or "Don't say that; you are the least {blank} person I know!"
#
# Try your code with all three test sentences to make sure it's working properly!
#
# Hint: You can return to lecture practice 7 if you want similar examples

# %%
target_phrase = "I am " # Look for sentences that start with this
target_len = len(target_phrase) # The length of the target phrase will be important

test_01 = "I am stupid"
test_02 = "I am awesome"
test_03 = "I am ugly"

response = ""

if test_01.startswith(target_phrase):
    #TODO: Fill in the rest here

print(response)

# %% [markdown]
# ## Optional challenge (if you still have time during lab)
#
# Is it working? If so, it's time to move on to a challenge! There's a good chance your code won't be able to handle some of the other more complicated cases below. To challenge yourself, pick ONE of the following test cases below, and try to update your code so that it responds appropriately to that case as well.

# %%
test_04 = "Well, I am cringe"
test_05 = "I am cringe don't you think?"
test_06 = "I'm cringe"

response = ""

#TODO: Your code here

print(response)
